# %%
print('hello')
# Out:
# hello

# %%
def addition(a,b,c):
    return a+b+c 

def subtraction(a,b):
    return a-b 

def divide(a,b):
    if b==0:
        raise ('denominator can not be zero..')
    return a/b  

def multiplication (a,b,c):
    return a*b*c
